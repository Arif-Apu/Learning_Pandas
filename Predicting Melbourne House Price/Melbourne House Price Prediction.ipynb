# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import rcParams

import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = (14, 7)
plt.style.use('fivethirtyeight')
#sb.set_style('darkgrid')

# %%
address = ('Melbourne_housing_FULL.csv')
house = pd.read_csv(address, encoding = 'utf-8')
house.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
house.shape
# Out:
# (34857, 21)

# %% [markdown]
# ###### Rename a column

# %%
house.rename(columns = {'Bedroom2':'Bedroom'}, inplace = True)

# %%
house.rename(str.lower, axis='columns', inplace = True)
house.head()
# Out:
#        suburb             address  rooms type      price method sellerg  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          date  distance  postcode  ...  bathroom  car  landsize  buildingarea  \
# 0  03/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %% [markdown]
# ###### Checking the data types of columns

# %%
house.dtypes
# Out:
# suburb            object
# address           object
# rooms              int64
# type              object
# price            float64
# method            object
# sellerg           object
# date              object
# distance         float64
# postcode         float64
# bedroom          float64
# bathroom         float64
# car              float64
# landsize         float64
# buildingarea     float64
# yearbuilt        float64
# councilarea       object
# lattitude        float64
# longtitude       float64
# regionname        object
# propertycount    float64
# dtype: object

# %%
type(house['date'][0])
# Out:
# str

# %% [markdown]
# ###### Convert Date data type

# %%
house['date'] = pd.to_datetime(house.date)

# %%
type(house['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
house.head()
# Out:
#        suburb             address  rooms type      price method sellerg  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         date  distance  postcode  ...  bathroom  car  landsize  buildingarea  \
# 0 2016-03-09       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1 2016-03-12       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2 2016-04-02       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3 2016-04-02       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4 2017-04-03       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %% [markdown]
# ###### Checking Missing values

# %%
house.isnull().head()
# Out:
#    suburb  address  rooms   type  price  method  sellerg   date  distance  \
# 0   False    False  False  False   True   False    False  False     False
# 1   False    False  False  False  False   False    False  False     False
# 2   False    False  False  False  False   False    False  False     False
# 3   False    False  False  False   True   False    False  False     False
# 4   False    False  False  False  False   False    False  False     False
#
#    postcode  ...  bathroom    car  landsize  buildingarea  yearbuilt  \
# 0     False  ...     False  False     False          True       True
# 1     False  ...     False  False     False          True       True
# 2     False  ...     False  False     False         False      False
# 3     False  ...     False  False     False          True       True
# 4     False  ...     False  False     False         False      False
#
#    councilarea  lattitude  longtitude  regionname  propertycount
# ...

# %%
house.isnull().sum()
# Out:
# suburb               0
# address              0
# rooms                0
# type                 0
# price             7610
# method               0
# sellerg              0
# date                 0
# distance             1
# postcode             1
# bedroom           8217
# bathroom          8226
# car               8728
# landsize         11810
# buildingarea     21115
# yearbuilt        19306
# councilarea          3
# lattitude         7976
# longtitude        7976
# regionname           3
# propertycount        3
# dtype: int64

# %%
house['price'].head(10)
# Out:
# 0          NaN
# 1    1480000.0
# 2    1035000.0
# 3          NaN
# 4    1465000.0
# 5     850000.0
# 6    1600000.0
# 7          NaN
# 8          NaN
# 9          NaN
# Name: price, dtype: float64

# %%
house.price.mean()
# Out:
# 1050173.344955408

# %%
house.price.mode()
# Out:
# 0     600000.0
# 1    1100000.0
# dtype: float64

# %% [markdown]
# ### Filling The Missing values by its average values. e,g average price, average rooms

# %%
house['price'].fillna(house.price.mean(), inplace = True)

# %%
house['price'].head()
# Out:
# 0    1.050173e+06
# 1    1.480000e+06
# 2    1.035000e+06
# 3    1.050173e+06
# 4    1.465000e+06
# Name: price, dtype: float64

# %%
house.agg({'price': ['sum', 'mean'], 'distance': ['sum', 'mean'], 'landsize': ['sum', 'mean']})
# Out:
#              price       distance      landsize
# sum   3.660589e+10  389861.900000  1.368068e+07
# mean  1.050173e+06      11.184929  5.935990e+02

# %% [markdown]
# ###### Rounding the average to the nearest value

# %%
#round(np.mean(house['bedroom']))
round(house['bedroom'].mean())
# Out:
# 3

# %%
np.mean(house['bathroom'])
# Out:
# 1.624798167549097

# %%
round(np.mean(house['bathroom']))
# Out:
# 2

# %%
house['bedroom'].fillna(round(house.bedroom.mean()), inplace = True)

# %%
house['bathroom'].fillna(round(house.bathroom.mean()), inplace = True)

# %%
house.buildingarea.mean()
# Out:
# 160.2564003565711

# %%
house.landsize.mean()
# Out:
# 593.598993361392

# %%
house.distance.fillna(house.distance.median(), inplace = True)

# %%
house['car'].fillna(0, inplace = True)

# %%
np.mean(house['landsize'])
# Out:
# 593.598993361392

# %%
np.mean(house['buildingarea'])
# Out:
# 160.2564003565711

# %%
house['buildingarea'].fillna(round(house.buildingarea.mean()), inplace = True)

# %%
house['landsize'].fillna(round(house.landsize.mean()), inplace = True)

# %%
house.isnull().sum()
# Out:
# suburb               0
# address              0
# rooms                0
# type                 0
# price                0
# method               0
# sellerg              0
# date                 0
# distance             0
# postcode             1
# bedroom              0
# bathroom             0
# car                  0
# landsize             0
# buildingarea         0
# yearbuilt        19306
# councilarea          3
# lattitude         7976
# longtitude        7976
# regionname           3
# propertycount        3
# dtype: int64

# %% [markdown]
# ###### Average price of Type H Houses

# %%
mean_typeh = house[house['type'] == 'h'].sort_values("date", ascending=False).groupby("date").price.mean()

# %%
mean_typeh.plot()
plt.title('Average price of type H houses By Dates')
plt.ylabel('Average Prices (€)')
plt.xlabel('Dates')
plt.show()

# %% [markdown]
# ###### Prices of All types houses

# %%
typeh = house.loc[house.type == 'h']['price']
typeu = house.loc[house.type == 'u']['price']
typet =house.loc[house.type == 't']['price']

types = [typeh, typeu, typet]

labels = ['Type H', 'Type U', 'Type T']
plt.title('Prices of all types Houses')
plt.ylabel('Prices')

boxes = plt.boxplot(types, labels = labels, notch = False, patch_artist = True)

# %%
sb.distplot(house['price']);

# %% [markdown]
# ###### Top house seller

# %%
colors = ['#bf4ea7','#884ebf', '#4ebf85', '#52bf4e', '#bf614e', '#bfb74e', '#bf834e', '#bf4e57']

house['sellerg'].value_counts().head(8).plot(kind = 'bar',  color = colors, rot = 30)

plt.title('Top 8 House Seller', fontsize = 14)
plt.ylabel('Total Number', fontsize = 14)
plt.xlabel('Seller', fontsize = 14)
plt.show()

# %%
sb.pairplot(house);
# Out:
# C:\Users\Apu\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Apu\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sb.lmplot('buildingarea', 'price', house[(house["bedroom"] <= 3) & (house["bathroom"] == 2) & 
                                         (house["price"]< 1000000)
                                      ], size = 15, hue = "type");
# Out:
# C:\Users\Apu\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sb.lmplot('landsize', 'price', house[(house["bedroom"] <= 3) & (house["bathroom"] == 2) & 
                                         (house["price"] < 2000000)
                                      ], size = 15, hue = "type");

# %%
sb.heatmap(house[house["type"] == "u"].corr(), annot=True, cmap= 'coolwarm');

# %%
sb.pairplot(house[['bedroom','rooms','bathroom','distance']], 
                  hue = 'bathroom', palette='tab20',size=6);
# Out:
# C:\Users\Apu\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Apu\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Apu\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Apu\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Apu\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %% [markdown]
# ###### Predicting Price using train_test_split Method

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
X = house['rooms'].values.reshape(-1, 1)
y = house['price'].values.reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([[236830.97863852]])

# %%
reg.score(X, y)
# Out:
# 0.1639242117142784

# %%
reg.intercept_
# Out:
# array([335254.93051302])

# %%
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([[ 808916.88779007],
#        [ 808916.88779007],
#        [ 808916.88779007],
#        ...,
#        [1045747.86642859],
#        [ 808916.88779007],
#        [ 808916.88779007]])

# %%
plt.scatter(X_test, y_test,  color = '#fc7889')
plt.plot(X_test, y_pred, color = '#08777a', linewidth=2)
plt.show()

# %%
sb.distplot(y_pred)

# %% [markdown]
# ###### Multiple variate

# %%
X = house[['buildingarea', 'rooms', 'bedroom', 'bathroom', 'distance','landsize']]
y = house['price'].values.reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
linreg = linear_model.LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linreg.coef_
# Out:
# array([[ 4.07927515e+01,  2.86577140e+05, -4.64070775e+04,
#          1.01503606e+05, -2.59558729e+04,  4.38519703e+00]])

# %%
linreg.score(X, y)
# Out:
# 0.2711334225853824

# %%
X_train.shape
# Out:
# (24399, 6)

# %%
y_train.shape
# Out:
# (24399, 1)

# %%
y_pred = linreg.predict(X_test)

# %%
y_pred
# Out:
# array([[1619116.05705394],
#        [ 591520.00013635],
#        [1382686.46245694],
#        ...,
#        [ 704523.10752428],
#        [1161923.53519787],
#        [1288059.73755268]])

# %%
sb.distplot(y_pred, kde = True, color = '#fcbe37', bins = 100);
